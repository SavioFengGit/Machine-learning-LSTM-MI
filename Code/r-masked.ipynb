# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
pip install ngram
# Out:
# ...
#   Created wheel for ngram: filename=ngram-3.3.2-cp37-none-any.whl size=24713 sha256=464f5f1a3968f6c80d9d140bba76a22af19ae224f973334bfe08462f30335b14
#   Stored in directory: /root/.cache/pip/wheels/7b/d5/5a/6abe3035c83a606376089accde30b021ffb26593f0d6609ef1
# Successfully built ngram
# ...

# %%
pip install statistics
# Out:
# ...
#   Created wheel for statistics: filename=statistics-1.0.3.5-cp37-none-any.whl size=7454 sha256=a0d4c1a78c4a53c58c58d9804d9d96ac6152f7c7a01da99ebb9eb33f0585b2a2
#   Stored in directory: /root/.cache/pip/wheels/75/55/90/73aa7662bfb4565b567618547a275f01372a678ca92ecd64f3
# Successfully built statistics
# ...

# %%
import pandas as pd
import numpy as np
#import sys
#sys.path.append('/content/drive/MyDrive/Cyber Security/grams_data')

# %%
import signal
import sys
from ngram import NGram
import itertools
import collections
import statistics

# %% [markdown]
# # DATASET

# %%
dataset_1 = pd.read_csv("/content/drive/MyDrive/Cyber Security/dga_domains_full.csv", encoding= "latin1", index_col = 0)
dataset_2 = pd.read_csv("/content/drive/MyDrive/Cyber Security/dga_domains_sample.csv", encoding= "latin1", index_col = 0)

# %%
colnames=['tipo', 'family', 'domain'] 
df = pd.read_csv("/content/drive/MyDrive/Cyber Security/dga_domains_full.csv", sep=',', encoding="latin1", names=colnames)
df.head()
# Out:
#     tipo   family                            domain
# 0    dga     gozi            mortiscontrastatim.com
# 1    dga  corebot  cvyh1po636avyrsxebwbkn7.ddns.net
# 2  legit    alexa                plasticbags.sa.com
# 3  legit    alexa                      mzltrack.com
# 4  legit    alexa                      miss-slim.ru

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 674898 entries, 0 to 674897
# Data columns (total 3 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   tipo    674898 non-null  object
#  1   family  674898 non-null  object
#  2   domain  674898 non-null  object
# dtypes: object(3)
# memory usage: 15.4+ MB

# %%
df_dga = df[df["tipo"] == "dga"]
df_dga.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 337500 entries, 0 to 674897
# Data columns (total 3 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   tipo    337500 non-null  object
#  1   family  337500 non-null  object
#  2   domain  337500 non-null  object
# dtypes: object(3)
# memory usage: 10.3+ MB

# %%
df_legit = df[df["tipo"] == "legit"]
df_legit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 337398 entries, 2 to 674895
# Data columns (total 3 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   tipo    337398 non-null  object
#  1   family  337398 non-null  object
#  2   domain  337398 non-null  object
# dtypes: object(3)
# memory usage: 10.3+ MB

# %%
sample_len = 0
if sample_len > 0:
  balanced_d = pd.concat([df_legit.sample(sample_len), df_dga.sample(sample_len)])
else:
  balanced_d = pd.concat([df_legit, df_dga.sample(len(df_legit))])
print(balanced_d.shape)
balanced_d.head()
# Out:
# (674796, 3)
#      tipo family                   domain
# 2   legit  alexa       plasticbags.sa.com
# 3   legit  alexa             mzltrack.com
# 4   legit  alexa             miss-slim.ru
# 6   legit  alexa        myhostingpack.com
# 12  legit  alexa  download-by-satoshi.com

# %%
df_dga_1 = balanced_d[balanced_d["tipo"] == "dga"]
del df_dga_1['family']
del df_dga_1['tipo']
df_dga_1.head()
# Out:
#                                   domain
# 505380                 kmbnvnhxqkpop.com
# 658293  machineboneroomdiscountcrash.com
# 217716                      iunabzrg.com
# 471464               icfkdyjhwnwrlee.com
# 331405                thumbsentering.net

# %%
df_legit_1 = balanced_d[balanced_d["tipo"] == "legit"]
del df_legit_1['family']
del df_legit_1['tipo']
df_legit_1.head()
# Out:
#                      domain
# 2        plasticbags.sa.com
# 3              mzltrack.com
# 4              miss-slim.ru
# 6         myhostingpack.com
# 12  download-by-satoshi.com

# %%
if sample_len > 0:
  df_dga_1.to_csv(r"/content/drive/MyDrive/Cyber Security/grams_data/dga-32K.txt", index=False, header=False)
  df_legit_1.to_csv(r"/content/drive/MyDrive/Cyber Security/grams_data/alexa-32K.txt", index=False, header=False)
else:
  df_dga_1.to_csv(r"/content/drive/MyDrive/Cyber Security/grams_data/dga-completo.txt", index=False, header=False)
  df_legit_1.to_csv(r"/content/drive/MyDrive/Cyber Security/grams_data/alexa-completo.txt", index=False, header=False)

# %% [markdown]
# # ALGORITMO

# %% [markdown]
# ## Create files CSV

# %%
file_name_dga =

# %%
# !python drive/MyDrive/Cyber\ Security/grams_data/top15_features.py "CLEAN" drive/MyDrive/Cyber\ Security/grams_data/alexa-completo.txt > drive/MyDrive/Cyber\ Security/grams_data/clean_completo.csv

# %%
# !python drive/MyDrive/Cyber\ Security/grams_data/top15_features.py "MALWARE" drive/MyDrive/Cyber\ Security/grams_data/dga-completo.txt > drive/MyDrive/Cyber\ Security/grams_data/dga_completo.csv

# %% [markdown]
# Esempio

# %%
# !python drive/MyDrive/Cyber\ Security/grams_data/top15_features.py "CLEAN" drive/MyDrive/Cyber\ Security/grams_data/esempio/alexa-32k.txt > drive/MyDrive/Cyber\ Security/grams_data/clean.csv

# %%
# !python drive/MyDrive/Cyber\ Security/grams_data/top15_features.py "MALWARE" drive/MyDrive/Cyber\ Security/grams_data/esempio/dga-32k.txt > drive/MyDrive/Cyber\ Security/grams_data/dga.csv

# %% [markdown]
# ## R

# %%
# %load_ext rpy2.ipython

# %%
# %%R
# install.packages("caret")
# install.packages("randomForest")
# install.packages("pROC")
# install.packages("e1071")
# Out:
# R[write to console]: Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# R[write to console]: also installing the dependencies ‘numDeriv’, ‘SQUAREM’, ‘lava’, ‘prodlim’, ‘iterators’, ‘gower’, ‘ipred’, ‘timeDate’, ‘foreach’, ‘plyr’, ‘ModelMetrics’, ‘reshape2’, ‘recipes’, ‘pROC’
#
#
# R[write to console]: trying URL 'https://cran.rstudio.com/src/contrib/numDeriv_2016.8-1.1.tar.gz'
#
# R[write to console]: Content type 'application/x-gzip'
# R[write to console]:  length 76053 bytes (74 KB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# ...

# %%
# %%R
# # Load libraries
# library(caret)
# library(randomForest)
# library(pROC)
# #library(devtools)
# #library(reprtree)
#
# # Set directory
# # setwd("/dga")
#
# print("Loading data")
#
# # Load original data
# clean   <- read.table( "drive/MyDrive/Cyber\ Security/grams_data/csv/clean.csv", header=FALSE, sep=",", na.strings="NaN", dec=",", strip.white=TRUE)
# dga     <- read.table( "drive/MyDrive/Cyber\ Security/grams_data/csv/dga.csv",   header=FALSE, sep=",", na.strings="NaN", dec=",", strip.white=TRUE)
#
# print("data loaded")
#
# m = ncol(clean)
#
# # Convert to numeric (disabled, weird result)
# for (j in 4:m)
# {
#     clean[,j]   <- as.numeric( clean[,j]   )
#     dga[,j]     <- as.numeric( dga[,j]     )
# }
#
# # Split in usable data and additional information
# selected_rows = 3:ncol(clean)
# #selected_rows1 <- c('V3', 'V21', 'V16','V20','V19', 'V5', 'V6'),
# #selected_rows2 <- c('V3', 'V24', 'V16','V20','V23', 'V6', 'V5'),
# #selected_rows3 <- c('V3', 'V84', 'V16','V20','V27', 'V6', 'V5'),
# #selected_rows4 <- c('V3', 'V16', 'V184','V20','V19', 'V89', 'V5'),
# #selected_rows <- selected_rows3
#
# data_clean_full <- clean[,selected_rows]
# data_dga_full   <- dga[,selected_rows]
# data <- rbind( data_clean_full, data_dga_full )
#
# # Create train and test sets for each dataset
# set.seed(1234)
#
# print("Selecting train and test data set")
# splitIndex <- createDataPartition(data$V3, p = .60,list = FALSE,times = 1)
# trainSplit      <- data[splitIndex,]
# testSplit       <- data[-splitIndex,]
# print("Done")
#
# # Remove old variables
# rm( clean, dga, splitIndex, data_clean_full, data_dga_full )
#
# #### CLASSIFIERS #### => https://topepo.github.io/caret/modelList.html
#
# set.seed(1234)
#
# # Train control
# print("Train control")
# ctrl <- trainControl(method = "repeatedcv",repeats = 3,classProbs = TRUE,summaryFunction = twoClassSummary)
# print("Done")
#
# # Random Forest with the small training set
# print("Training...")
# system.time({
# rfFit <- train(V3~.,data = trainSplit,method = "rf",trControl = ctrl,metric = "ROC")
# })
# print("Done")
#
# # Test with the test set
# print("Testing...")
# system.time({
# rfPred <- predict(rfFit, testSplit)
# })
# print("Done")
#
# print("Results...")
# importance = varImp(rfFit)
# importance
#
# # Confusion matrix
# confusionMatrix(rfPred, testSplit[,1])
#
# #print("Printing a demo tree...")
# #reprtree:::plot.getTree(rfFit$finalModel)
# Out:
# R[write to console]: Loading required package: lattice
#
# R[write to console]: Loading required package: ggplot2
#
# R[write to console]: randomForest 4.6-14
#
# R[write to console]: Type rfNews() to see new features/changes/bug fixes.
#
# R[write to console]:
# Attaching package: ‘randomForest’
#
#
# R[write to console]: The following object is masked from ‘package:ggplot2’:
#
#     margin
#
#
# R[write to console]: Type 'citation("pROC")' for a citation.
#
# R[write to console]:
# Attaching package: ‘pROC’
#
#
# R[write to console]: The following objects are masked from ‘package:stats’:
#
#     cov, smooth, var
# [1] "Loading data"
# [1] "data loaded"
# [1] "Selecting train and test data set"
# [1] "Done"
# [1] "Train control"
# [1] "Done"
# [1] "Training..."
# [1] "Done"
# [1] "Testing..."
# [1] "Done"
# [1] "Results..."
# R[write to console]: Error: `data` and `reference` should be factors with the same levels.
#
# R[write to console]: In addition:
# ...

# %% [markdown]
# # GIT

# %%
# !git clone https://github.com/jselvi/docker-r-masked-ngrams.git
# Out:
# fatal: destination path 'LSTM-MI' already exists and is not an empty directory.
# Cloning into 'docker-r-masked-ngrams'...
# remote: Enumerating objects: 18, done.
# remote: Counting objects: 100% (18/18), done.
# remote: Compressing objects: 100% (17/17), done.
# remote: Total 18 (delta 2), reused 13 (delta 1), pack-reused 0
# Unpacking objects: 100% (18/18), done.
# Cloning into 'bilbo-bagging-hybrid'...
# remote: Enumerating objects: 104, done.
# remote: Counting objects: 100% (104/104), done.
# remote: Compressing objects: 100% (94/94), done.
# remote: Total 104 (delta 46), reused 22 (delta 4), pack-reused 0
# Receiving objects: 100% (104/104), 9.71 MiB | 17.75 MiB/s, done.
# Resolving deltas: 100% (46/46), done.
# Cloning into 'CapsNet-Keras'...
# remote: Enumerating objects: 235, done.
# remote: Total 235 (delta 0), reused 0 (delta 0), pack-reused 235
# Receiving objects: 100% (235/235), 1.06 MiB | 6.73 MiB/s, done.
# Resolving deltas: 100% (117/117), done.
